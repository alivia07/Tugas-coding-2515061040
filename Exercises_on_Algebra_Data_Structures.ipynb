# %%
import numpy as np

# %%
v = np.array([[25], [2], [-3], [-23]])
v
# Out:
# array([[ 25],
#        [  2],
#        [ -3],
#        [-23]])

# %%
v.T
print("transpose dari vector v adalah:", v.T)
# Out:
# transpose dari vector v adalah: [[ 25   2  -3 -23]]
