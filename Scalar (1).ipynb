# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x = 72
x
# Out:
# 72

# %%
# tampilkan tipe data dari x
type (x)
# Out:
# int

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 7

# %%
# tampilkan tipe data dari y
type (y)
# Out:
# int

# %%
# jumlahkan x+y
py_sum = x + y
py_sum
# Out:
# 79

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 1.040

# %%
# jumlahkan x_float dengan y
sum_float = x_float + y
sum_float
# Out:
# 8.04

# %%
# tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %%
import tensorflow as tf

# %%
# lakukan tahapan pada soal 1 dengan menggunakan tensorflow
x_tf = tf.Variable(10.40)
x_tf
print(f"variabel tensor x adalah :", x_tf)
# Out:
# variabel tensor x adalah : <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=10.399999618530273>

# %%
y_tf2 = tf.Variable(40.10)
print(f"variabel tensor y adalah :", y_tf2)
# Out:
# variabel tensor y adalah : <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=40.099998474121094>

# %%
x_tf.shape
# Out:
# TensorShape([])

# %%
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=50.5>

# %%
tf_sum = tf.add(x_tf, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=50.5>

# %%
tf_sum.numpy()
# Out:
# np.float32(50.5)

# %%
type(tf_sum.numpy())
# Out:
# numpy.float32

# %%
tf_float = tf.Variable(25., dtype=tf.float16)
tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=25.0>

# %%
# lakukan tahapan pada soal 1 dengan menggunakan pytorch

import torch

# %%
x_pt = torch.tensor(40)
x_pt
# Out:
# tensor(40)

# %%
x_pt.shape
# Out:
# torch.Size([])
