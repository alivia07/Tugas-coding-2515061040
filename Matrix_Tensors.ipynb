# %%
import numpy as np

# %%
# buat matrix X berukuran 2x3 menggunakan numpy
X = np.array([[6, 10, 40], [72, 27, 57]])
X
# Out:
# array([[ 6, 10, 40],
#        [72, 27, 57]])

# %%
# tampilkan ukuran dari matrix X
X.shape
# Out:
# (2, 3)

# %%
X.size
# Out:
# 6

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X[:,0]
# Out:
# array([ 6, 72])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
X[1,:]
# Out:
# array([72, 27, 57])

# %%
# ulangi soal nomor 1 menggunakan pytorch
import torch

# %%
X_pt = torch.tensor([[6, 10, 40], [72, 27, 57]])
X_pt
# Out:
# tensor([[ 6, 10, 40],
#         [72, 27, 57]])

# %%
X_pt.shape
# Out:
# torch.Size([2, 3])

# %%
X_pt[1,:]
# Out:
# tensor([72, 27, 57])

# %%
# ulangi soal nomor 1 menggunakan tensorflow
import tensorflow as tf

# %%
X_tf = tf.Variable([[6, 10, 40], [72, 27, 57]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[ 6, 10, 40],
#        [72, 27, 57]], dtype=int32)>

# %%
tf.rank(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>

# %%
tf.shape(X_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2, 3], dtype=int32)>

# %%
X_tf[1,:]
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([72, 27, 57], dtype=int32)>
